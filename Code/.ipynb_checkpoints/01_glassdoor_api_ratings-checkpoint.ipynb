# %% [markdown]
# # Pulling Data from Glassdoor API
# * * * * *
# This file will setup and test the API GET request to pull company ratings from Glassdoor's API. It will then load all of the companies I am interested in collecting ratings on, run the request, and then save the ratings data to a new csv.

# %%
# Import required libraries
import requests
import urllib
import json
from __future__ import division
import math
import os
import re
from operator import itemgetter
from itertools import groupby

# %% [markdown]
# ## Constructing API GET Request
#
# Setting up the basic variables to call.

# %%
# set base url
base_url="http://api.glassdoor.com/api/api.htm?"

# set response format
response_format=".json"

# set search parameters
search_params = {"v":"1",
                "format":"json",
                "t.k": "Glassdoor Partner ID Goes Here",
                "t.p": "Glassdoor Partner Key Goes Here",
                "userip":"My IP Address",
                "useragent":"Chrome/53.0.2785.116",
                "action":"employers",
                 "q":"3M"}

# %%
#testing the url works
r = requests.get(base_url+response_format, params=search_params, headers={"User-Agent":"Chrome/53.0.2785.116"})

print(r.url)
# Out:
# http://api.glassdoor.com/api/api.htm?.json&useragent=Chrome%2F53.0.2785.116&format=json&action=employers&v=1&q=3M&t.k=eoptK2zAcqi&userip=136.152.142.46&t.p=98187

# %%
response_text= r.text

# %%
# Convert JSON response to a dictionary
data=json.loads(response_text)
data.keys()
# Out:
# dict_keys(['status', 'jsessionid', 'success', 'response'])

# %%
#looking at what it calls
data['response']['employers'][0]
# Out:
# {'careerOpportunitiesRating': '3.4',
#  'ceo': {'image': {'height': 200,
#    'src': 'https://media.glassdoor.com/people/sqll/446/3m-inge-g-thulin.png',
#    'width': 200},
#   'name': 'Inge G. Thulin',
#   'numberOfRatings': 482,
#   'pctApprove': 86,
#   'pctDisapprove': 14,
#   'title': 'Chairman President & CEO'},
#  'compensationAndBenefitsRating': '3.7',
#  'cultureAndValuesRating': '3.7',
#  'exactMatch': True,
#  'featuredReview': {'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-3M-RVW12548978.htm',
#   'cons': 'bad management, favoritism, bending of company policies,',
#   'currentJob': True,
#   'headline': 'operator',
#   'id': 12548978,
#   'jobTitle': 'Employee',
#   'location': '',
#   'overall': 4,
#   'overallNumeric': 4,
#   'pros': 'Good pay, overtime, benefits, good work environment',
#   'reviewDateTime': '2016-11-03 13:19:49.283'},
#  'id': 446,
#  'industry': 'Chemical Manufacturing',
#  'industryId': 200068,
#  'industryName': 'Chemical Manufacturing',
#  'isEEP': False,
#  'name': '3M',
#  'numberOfRatings': 1357,
#  'overallRating': '3.7',
#  'ratingDescription': 'Satisfied',
#  'recommendToFriendRating': 75,
#  'sectorId': 10015,
#  'sectorName': 'Manufacturing',
#  'seniorLeadershipRating': '3.2',
#  'squareLogo': 'https://media.glassdoor.com/sqll/446/3m-squarelogo.png',
#  'website': 'www.3m.com',
#  'workLifeBalanceRating': '3.5'}

# %% [markdown]
# ## Loading dataset with companies to search
#
# Loading previously downloaded dataset with all the companies that need to be searched in the Glassdoor ratings database.

# %%
print(os.path.abspath(os.curdir)) #check current wd
# Out:
# /Users/Rosie/Box Sync/Berkeley/Fall 2016/PolSci239T/PS239T-final-project/Code

# %%
import csv
companylist=[]
os.chdir("..") #move 1 wd up
with open('./Data/01_glassdoor_ceo_pay.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        companylist.append(row['company'])

# %%
#making sure this worked as expected and produced a list
type(companylist)
# Out:
# list

# %%
#Should list all the companies, and it does.
print(companylist)
# Out:
# ['3M', 'Abbott Labs', 'AbbVie', 'Accenture', 'ACE Group', 'ADM', 'Adobe', 'ADP', 'ADT Security Services', 'Advance Auto Parts', 'AEP', 'AES Corporation', 'Aetna', 'Aflac', 'Agilent Technologies', 'AIG', 'Aimco Apartment Homes', 'Air Products', 'Airgas', 'Akamai', 'Alcoa', 'Allergan', 'Alliance Data', 'Allstate', 'Altera', 'Altria', 'Amazon.com', 'Ameren', 'American Airlines', 'American Express', 'American Tower', 'Ameriprise', 'AmerisourceBergen', 'AMETEK', 'Amgen', 'Anadarko Petroleum', 'Analog Devices', 'Anthem', 'Aon', 'Apache', 'Apple', 'Applied Materials', 'Assurant', 'AT&T', 'Autodesk', 'AutoNation', 'AutoZone', 'Avago Technologies', 'AvalonBay', 'Avery Dennison', 'Baker Hughes', 'Bank of America', 'Bard', 'Baxter', 'BB&T', 'BD', 'Bed Bath & Beyond', 'Best Buy', 'Biogen Idec', 'BlackRock', 'BNY Mellon', 'Boeing', 'BorgWarner', 'Boston Scientific', 'Bristol-Myers Squibb', 'Broadcom', 'Brown-Forman', 'C.H. Robinson Worldwide', 'CA Technologies', 'Cablevision Systems', 'Cameron', 'Campbell Soup Company', 'Capital One', 'Cardinal Health', 'CarMax', 'Carnival Corporation', 'Caterpillar', 'CBRE', 'CBS Corp', 'Celgene', 'CenterPoint Energy', 'CenturyLink', 'Cerner', 'Charles Schwab', 'Chesapeake Energy', 'Chevron', 'Chipotle', 'Chubb Corp', 'Cigna', 'Cintas', 'Cisco Systems', 'Citi', 'Citrix Systems', 'Clorox', 'CME Group', 'Coach', 'Coca-Cola Company', 'Coca-Cola Enterprises, Inc.', 'Cognizant Technology Solutions', 'Colgate-Palmolive', 'Comcast', 'Comerica', 'Computer Sciences Corp', 'Con Edison', 'ConAgra Foods', 'ConocoPhillips', 'CONSOL Energy', 'Constellation Brands', 'Corning', 'Costco Wholesale', 'Crown Castle', 'CSX', 'Cummins', 'CVS Health', 'D.R. Horton', 'Danaher', 'Darden', 'DaVita', 'Delphi', 'Delta Air Lines', 'DENTSPLY International', 'Devon Energy', 'Discover', 'Discovery Communications', 'Dollar General', 'Dollar Tree', 'Dominion Resources', 'Dow Chemical', 'Dr Pepper Snapple Group', 'DTE Energy', 'Duke Energy', 'Dun & Bradstreet', 'DuPont', 'E*TRADE Financial', 'Eastman Chemical', 'Eaton', 'eBay', 'Ecolab', 'Edwards Lifesciences', 'Electronic Arts', 'Eli Lilly', 'EMC', 'Emerson', 'Endo Pharmaceuticals', 'Entergy', 'EOG', 'Equifax', 'Equinix', 'Equity Residential', 'Essex Property Trust', 'Estee Lauder Companies', 'Exelon', 'Expedia', 'Expeditors', 'Express Scripts', 'ExxonMobil', 'F5 Networks', 'Facebook', 'Fastenal', 'FedEx', 'Fifth Third', 'First Solar', 'FirstEnergy', 'FIS', 'Fiserv', 'FLIR', 'Flowserve', 'Fluor', 'FMC', 'FMC Technologies', 'Ford Motor Company', 'Fossil', 'Franklin Templeton Investments', 'Freeport-McMoRan Copper & Gold', 'Frontier Communications', 'GameStop', 'Gap', 'Garmin', 'GE', 'General Dynamics', 'General Growth Properties', 'General Mills', 'General Motors', 'Genuine Parts', 'Genworth Financial', 'Gilead Sciences', 'Goldman Sachs', 'Goodyear', 'Google', 'H&R Block', 'Halliburton', 'Hanesbrands', 'Harley-Davidson', 'HARMAN', 'Harris', 'Hasbro', 'Henry Schein', 'Hess Corporation', 'Hewlett-Packard', 'Honeywell', 'Hormel', 'Hospira', 'Hospital Corporation of America', 'Humana', 'Huntington National Bank', 'IBM', 'Illinois Tool Works', 'Ingersoll Rand', 'Intel Corporation', 'Intercontinental Exchange', 'International Flavors & Fragrances', 'International Paper', 'Interpublic Group', 'Intuit', 'Intuitive Surgical', 'Invesco', 'Iron Mountain Inc', 'J.B. Hunt', 'J.P. Morgan', 'Jacobs', 'John Deere', 'Johnson & Johnson', 'Johnson Controls', 'Joy Global', 'Juniper Networks', 'Kellogg Company', 'Keurig Green Mountain', 'KeyBank', 'Kimberly-Clark', 'Kinder Morgan', 'KLA-Tencor', "Kohl's", 'Kroger', 'L Brands', 'L-3 Communications', 'LabCorp', 'Lam Research', 'Legg Mason', 'Leggett & Platt', 'Lennar', 'Level 3 Communications', 'Lincoln Financial Group', 'Linear Technology', 'Lockheed Martin', "Lowe's", 'LyondellBasell', 'M&T Bank', 'Macerich', "Macy's", 'Mallinckrodt Pharmaceuticals', 'Marathon Oil', 'Marathon Petroleum', 'Marriott', 'Marsh & McLennan Companies', 'Masco', 'MasterCard', 'Mattel' ...

# %% [markdown]
# ## Testing & accounting for errors in the GET request
#
# After running the code a few times, I discovered there were some errors in how the company names were stored, which generated errors when running the API code (all should now be fixed). This was some code I created to test for errors and keep track of them while continuing to run through the for loop.

# %%
search_params = []
search_params = {"v":"1",
                "format":"json",
                "t.k": "eoptK2zAcqi",
                "t.p": "98187",
                "userip":"136.152.142.46",
                "useragent":"Chrome/53.0.2785.116",
                "action":"employers",
                 "q":"Accenture"}
r = requests.get(base_url+response_format, params=search_params, headers={"User-Agent":"Chrome/53.0.2785.116"})
response_text= r.text
data=json.loads(response_text)
try:
    data1 = data['response']['employers'][0]
    print(data1)
except IndexError:
    print("broken")
# Out:
# {'squareLogo': 'https://media.glassdoor.com/sqll/4138/accenture-squarelogo-1446040583582.png', 'isEEP': True, 'featuredReview': {'jobTitle': 'Infrastructure Manager', 'currentJob': True, 'overallNumeric': 5, 'cons': 'This is not an opportunity for those that do not want to work. At Accenture everyone has a load of work to do and often times under very tight customer time lines. It is a challenge that I enjoy but many might find it stressful.', 'pros': 'There are a lot of pros working for Accenutre. They have great career opportunities, a never ending supply of interesting work, competitive compensation, wonderful benefits, great people, wonderful training programs, a tremendous number of brilliant professionals in their fields ready to help, and great core values.', 'jobTitleFromDb': 'Infrastructure Manager', 'location': 'West Lafayette, IN', 'headline': 'Alot of Jobs One Home', 'reviewDateTime': '2015-09-21 06:13:54.03', 'id': 8020149, 'overall': 5, 'attributionURL': 'http://www.glassdoor.com/Reviews/Employee-Review-Accenture-RVW8020149.htm'}, 'seniorLeadershipRating': '3.2', 'ratingDescription': 'Satisfied', 'website': 'www.accenture.com', 'ceo': {'title': 'CEO', 'numberOfRatings': 8930, 'pctDisapprove': 6, 'pctApprove': 94, 'image': {'src': 'https://media.glassdoor.com/people/sqll/4138/accenture-pierre-nanterme.png', 'width': 200, 'height': 200}, 'name': 'Pierre Nanterme'}, 'cultureAndValuesRating': '3.7', 'compensationAndBenefitsRating': '3.4', 'workLifeBalanceRating': '3.2', 'careerOpportunitiesRating': '3.6', 'recommendToFriendRating': 81, 'numberOfRatings': 21188, 'overallRating': '3.7', 'id': 4138, 'industry': '', 'exactMatch': True, 'name': 'Accenture'}

# %% [markdown]
# ## Put it all together
#
# The loop below adds a new search parameter from the company list to be pulled from the API, makes note of errors, and stores the data in a new dataset.

# %%
import time
final_dic = []

for companyname in companylist:
    #Insert company name into search parameters
    search_params = []
    search_params = {"v":"1",
                "format":"json",
                "t.k": "eoptK2zAcqi",
                "t.p": "98187",
                "userip":"136.152.142.46",
                "useragent":"Chrome/53.0.2785.116",
                "action":"employers",
                 "q":str(companyname)}
    
    #Run through API
    r = requests.get(base_url+response_format, params=search_params, headers={"User-Agent":"Chrome/53.0.2785.116"})
    response_text= r.text
    data=json.loads(response_text)
    company = {}
    
    try:
        data1 = data['response']['employers'][0]

        #Collect relevant data from first company in the list
        company["id"] = data1["id"]
        company["company_ratings"] = data1["name"]
        company["industry"] = data1["industry"]
        company["numberOfRatings"] = data1["numberOfRatings"]
        company["ceo2016"] = data1["ceo"]["name"]
        company["ceoratings"] = data1["ceo"]["numberOfRatings"]
        company["ceopctApprove"] = data1["ceo"]["pctApprove"]
        company["overall"] = data1["overallRating"]
        company["careerops"] = data1["careerOpportunitiesRating"]
        company["comp"] = data1["compensationAndBenefitsRating"]
        company["culturevalues"] = data1["cultureAndValuesRating"]
        company["srleadership"] = data1["seniorLeadershipRating"]
        company["wlb"] = data1["workLifeBalanceRating"]
        company["rectofriend"] = data1["recommendToFriendRating"]
        company["error"] = "None"
        final_dic.append(company)
    
        #check its iterating correctly
        print(companyname + " = " + str(company["company_ratings"]) + " complete")
        
    except IndexError:
        company["company_ratings"] = str(companyname)
        company["error"] = "Index Error"
        final_dic.append(company)
        
        #show it's iterating errors
        print(companyname + " Index Error!!!!!")
        
    except KeyError:
        company["company_ratings"] = str(companyname)
        company["error"] = "Key Error"
        final_dic.append(company)
        
        #show it's iterating errors
        print(companyname + " Key Error!!!!!")
    
    time.sleep(1) #have it rest 1 second between searches
# Out:
# 3M = 3M complete
# Abbott Labs = Abbott Labs complete
# AbbVie = AbbVie complete
# Accenture = Accenture complete
# ACE Group = ACE Group complete
# ADM = ADM complete
# Adobe = Adobe complete
# ADP = ADP complete
# ADT Security Services = ADT Security Services complete
# Advance Auto Parts = Advance Auto Parts complete
# AEP = AEP complete
# AES Corporation = AES Corporation complete
# Aetna = Aetna complete
# Aflac = Aflac complete
# Agilent Technologies = Agilent Technologies complete
# AIG = AIG complete
# Aimco Apartment Homes = Aimco Apartment Homes complete
# Air Products = Air Products complete
# Airgas = Airgas complete
# Akamai = Akamai complete
# Alcoa = Alcoa complete
# Allergan = Allergan complete
# Alliance Data = Alliance Data complete
# Allstate = Allstate complete
# Altera = Altera complete
# Altria = Altria complete
# Amazon.com = Amazon.com complete
# Ameren = Ameren complete
# American Airlines = American Airlines complete
# American Express = American Express complete
# American Tower = American Tower complete
# Ameriprise = Ameriprise complete
# AmerisourceBergen = AmerisourceBergen complete
# AMETEK = AMETEK complete
# Amgen = Amgen complete
# Anadarko Petroleum = Anadarko Petroleum complete
# Analog Devices = Analog Devices complete
# Anthem = Anthem complete
# Aon = Aon complete
# Apache = Apache complete
# Apple = Apple complete
# Applied Materials = Applied Materials complete
# Assurant = Assurant complete
# AT&T = AT&T complete
# Autodesk = Autodesk complete
# AutoNation = AutoNation complete
# AutoZone = AutoZone complete
# Avago Technologies = Avago Technologies complete
# AvalonBay = AvalonBay complete
# Avery Dennison = Avery Dennison complete
# Baker Hughes = Baker Hughes complete
# Bank of America = Bank of America complete
# Bard = Bard complete
# Baxter = Baxter complete
# BB&T = BB&T complete
# BD = BD complete
# Bed Bath & Beyond = Bed Bath & Beyond complete
# Best Buy = Best Buy complete
# Biogen Idec = Biogen complete
# BlackRock = BlackRock complete
# BNY Mellon = BNY Mellon complete
# Boeing = Boeing complete
# BorgWarner = BorgWarner complete
# Boston Scientific = Boston Scientific complete
# Bristol-Myers Squibb = Bristol-Myers Squibb complete
# Broadcom = Broadcom complete
# Brown-Forman = Brown-Forman complete
# C.H. Robinson Worldwide = C.H. Robinson complete
# CA Technologies = CA Technologies complete
# Cablevision Systems = Cablevision Systems complete
# Cameron = Cameron complete
# Campbell Soup Company = Campbell Soup Company complete
# Capital One = Capital One complete
# Cardinal Health = Cardinal Health complete
# CarMax = CarMax complete
# Carnival Corporation = Carnival complete
# Caterpillar = Caterpillar complete
# CBRE = CBRE complete
# CBS Corp = CBS Corp complete
# Celgene = Celgene complete
# CenterPoint Energy = CenterPoint Energy complete
# CenturyLink = CenturyLink complete
# Cerner = Cerner complete
# Charles Schwab = Charles Schwab complete
# Chesapeake Energy = Chesapeake Energy complete
# Chevron = Chevron complete
# Chipotle = Chipotle complete
# Chubb Corp = Chubb complete
# Cigna = Cigna complete
# Cintas = Cintas complete
# Cisco Systems = Cisco Systems complete
# Citi = Citi complete
# Citrix Systems = Citrix complete
# Clorox = Clorox complete
# CME Group = CME Group complete
# Coach = Coach complete
# Coca-Cola Company = Coca-Cola Company complete
# Coca-Cola Enterprises, Inc. = Coca-Cola Enterprises, Inc. complete
# Cognizant Technology Solutions = Cognizant Technology Solutions complete
# Colgate-Palmolive = Colgate-Palmolive complete
# Comcast = Comcast complete
# Comerica = Comerica complete
# Computer Sciences Corp = CSC complete
# Con Edison = Con Edison complete
# ConAgra Foods = ConAgra Foods complete
# ConocoPhillips = ConocoPhillips complete
# CONSOL Energy = CONSOL Energy complete
# Constellation Brands = Constellation Brands complete
# Corning = Corning complete
# Costco Wholesale = Costco Wholesale complete
# Crown Castle = Crown Castle complete
# CSX = CSX complete
# Cummins = Cummins complete
# CVS Health = CVS Health complete
# D.R. Horton = D.R. Horton complete
# Danaher = Danaher complete
# Darden = Darden complete
# DaVita = DaVita complete
# Delphi = Delphi complete
# Delta Air Lines = Delta Air Lines complete
# DENTSPLY International = Dentsply Sirona complete
# Devon Energy = Devon Energy complete
# Discover = Discover complete
# Discovery Communications = Discovery Communications complete
# Dollar General = Dollar General complete
# Dollar Tree = Dollar Tree complete
# Dominion Resources = Dominion Resources complete
# Dow Chemical = Dow Chemical complete
# Dr Pepper Snapple Group = Dr Pepper Snapple Group complete
# DTE Energy = DTE Energy complete
# Duke Energy = Duke Energy complete
# Dun & Bradstreet = Dun & Bradstreet complete
# DuPont = DuPont complete
# E*TRADE Financial = E*TRADE Financial complete
# Eastman Chemical = Eastman complete
# Eaton = Eaton complete
# eBay = eBay complete
# Ecolab = Ecolab complete
# Edwards Lifesciences = Edwards Lifesciences complete
# Electronic Arts = Electronic Arts complete
# Eli Lilly = Eli Lilly complete
# EMC = EMC complete
# Emerson = Emerson complete
# Endo Pharmaceuticals = Endo Pharmaceuticals complete
# Entergy = Entergy complete
# EOG = EOG complete
# Equifax = Equifax complete
# Equinix = Equinix complete
# Equity Residential = Equity Residential complete
# Essex Property Trust = Essex Property Trust complete
# Estee Lauder Companies = Estée Lauder Companies complete
# Exelon = Exelon complete
# Expedia = Expedia complete
# Expeditors = Expeditors complete
# Express Scripts = Express Scripts complete
# ExxonMobil = ExxonMobil complete
# F5 Networks = F5 Networks complete
# Facebook = Facebook complete
# Fastenal = Fastenal complete
# FedEx = FedEx complete
# Fifth Third = Fifth Third complete
# First Solar = First Solar complete
# FirstEnergy = FirstEnergy complete
# FIS = FIS complete
# Fiserv = Fiserv complete
# FLIR = FLIR complete
# Flowserve = Flowserve complete
# Fluor = Fluor complete
# FMC = FMC complete
# FMC Technologies = FMC Technologies complete
# Ford Motor Company = Ford Motor Company complete
# Fossil = Fossil complete
# Franklin Templeton Investments = Franklin Templeton Investments complete
# Freeport-McMoRan Copper & Gold = Freeport-McMoRan Copper & Gold complete
# Frontier Communications = Frontier Communications complete
# GameStop = GameStop complete
# Gap = Gap complete
# Garmin = Garmin complete
# GE = GE complete
# General Dynamics = General Dynamics complete
# General Growth Properties = General Growth Properties complete
# General Mills = General Mills complete
# General Motors = General Motors complete
# Genuine Parts = Genuine Parts complete
# Genworth Financial = Genworth complete
# Gilead Sciences = Gilead Sciences complete
# Goldman Sachs = Goldman Sachs complete
# Goodyear = Goodyear complete
# Google = Google complete
# H&R Block = H&R Block complete
# Halliburton = Halliburton complete
# Hanesbrands = Hanesbrands complete
# Harley-Davidson = Harley-Davidson complete
# HARMAN = HARMAN complete
# Harris = Harris complete
# Hasbro = Hasbro complete
# Henry Schein = Henry Schein complete
# Hess Corporation = Hess Corporation complete
# Hewlett-Packard = Hewlett-Packard complete
# Honeywell = Honeywell complete
# Hormel = Hormel complete
# Hospira = Hospira complete
# Hospital Corporation of America = Hospital Corporation of America complete
# Humana = Humana complete
# Huntington National Bank = Huntington National Bank complete
# IBM = IBM complete
# Illinois Tool Works = Illinois Tool Works complete
# Ingersoll Rand = Ingersoll Rand complete
# Intel Corporation = Intel Corporation complete
# Intercontinental Exchange = Intercontinental Exchange complete
# International Flavors & Fragrances = International Flavors & Fragrances complete
# International Paper = International Paper complete
# Interpublic Group = Interpublic Group complete
# Intuit = Intuit complete
# Intuitive Surgical = Intuitive Surgical complete
# Invesco = Invesco complete
# Iron Mountain Inc = Iron Mountain Inc complete
# J.B. Hunt = J.B. Hunt complete
# J.P. Morgan = J.P. Morgan complete
# Jacobs = Jacobs complete
# John Deere = John Deere complete
# Johnson & Johnson = Johnson & Johnson complete
# Johnson Controls = Johnson Controls complete
# Joy Global = Joy Global complete
# Juniper Networks = Juniper Networks complete
# Kellogg Company = Kellogg Company complete
# Keurig Green Mountain = Keurig Green Mountain complete
# KeyBank = KeyBank complete
# Kimberly-Clark = Kimberly-Clark complete
# Kinder Morgan = Kinder Morgan complete
# KLA-Tencor = KLA-Tencor complete
# Kohl's = Kohl's complete
# Kroger = Kroger complete
# L Brands = L Brands complete
# L-3 Communications = L-3 Communications complete
# LabCorp = LabCorp complete
# Lam Research = Lam Research complete
# Legg Mason = Legg Mason complete
# Leggett & Platt = Leggett & Platt complete
# Lennar = Lennar complete
# Level 3 Communications = Level 3 Communications complete
# Lincoln Financial Group = Lincoln Financial Group complete
# Linear Technology = Linear Technology complete
# Lockheed Martin = Lockheed Martin complete
# Lowe's = Lowe's complete
# LyondellBasell = LyondellBasell complete
# M&T Bank = M&T Bank complete
# Macerich = Macerich complete
# Macy's = Macy's complete
# Mallinckrodt Pharmaceuticals = Mallinckrodt Pharmaceuticals complete
# Marathon Oil = Marathon Oil complete
# Marathon Petroleum = Marathon Petroleum complete
# Marriott = Marriott complete
# Marsh & McLennan Companies = Marsh & McLennan Companies complete
# Masco = Masco complete
# MasterCard = MasterCard complete
# Mattel = Mattel complete
# McCormick & Company = McCormick & Company complete
# McDonald's = McDonald's complete
# McGraw Hill Financial = McGraw Hill Financial complete
# McKesson = McKesson complete
# Mead Johnson = Mead Johnson complete
# Medtronic = Medtronic complete
# Merck = Merck complete
# MetLife = MetLife complete
# Michael Kors = Michael Kors complete
# Microchip Technology = Microchip Technology complete
# Micron Technology = Micron Technology complete
# Microsoft = Microsoft complete
# Mohawk Industries = Mohawk Industries complete
# Mondelez International = Mondelez International complete
# Monsanto Company = Monsanto Company complete
# Moody's = Moody's complete
# Morgan Stanley = Morgan Stanley complete
# Mosaic Company (Minnesota) = Mosaic Company (Minnesota) complete
# Motorola Solutions = Motorola Solutions complete
# Murphy Oil = Murphy Oil complete
# NASDAQ = Nasdaq complete
# National Oilwell Varco = National Oilwell Varco complete
# Navient = Navient complete
# NetApp = NetApp complete
# Netflix = Netflix complete
# Newell Rubbermaid = Newell Rubbermaid complete
# Newfield Exploration = Newfield Exploration complete
# Newmont Mining = Newmont Mining complete
# News Corp = News Corp complete
# NextEra Energy, Inc. = NextEra Energy, Inc. complete
# Nielsen = Nielsen complete
# NIKE = NIKE complete
# NiSource = NiSource complete
# Noble Energy = Noble Energy complete
# Nordstrom = Nordstrom complete
# Norfolk Southern = Norfolk Southern complete
# Northern Trust = Northern Trust complete
# Northrop Grumman = Northrop Grumman complete
# NRG Energy = NRG Energy complete
# Nucor = Nucor complete
# NVIDIA = NVIDIA complete
# O'Reilly Auto Parts = O'Reilly Auto Parts complete
# Occidental Petroleum = Occidental Petroleum complete
# Omnicom = Omnicom complete
# ONEOK = ONEOK complete
# Oracle = Oracle complete
# Owens-Illinois = Owens-Illinois complete
# PACCAR = PACCAR complete
# Pacific Gas and Electric = Pacific Gas and Electric complete
# Pall = Pall complete
# Parker Hannifin = Parker Hannifin complete
# Patterson Companies = Patterson Companies complete
# Paychex = Paychex complete
# Pentair = Pentair complete
# People's United Bank = People's United Bank complete
# Pepco Holdings = Pepco Holdings complete
# PepsiCo = PepsiCo complete
# PerkinElmer = PerkinElmer complete
# Perrigo = Perrigo complete
# Pfizer = Pfizer complete
# Phillips 66 = Phillips 66 complete
# Pitney Bowes = Pitney Bowes complete
# PNC Financial Services Group = PNC Financial Services Group complete
# Polo Ralph Lauren = Ralph Lauren complete
# PPG = PPG complete
# Praxair = Praxair complete
# Precision Castparts = Precision Castparts complete
# Priceline.com = Priceline.com complete
# Principal Financial Group = Principal Financial Group complete
# Procter & Gamble = Procter & Gamble complete
# Progressive Insurance = Progressive Insurance complete
# Prologis = Prologis complete
# Prudential = Prudential complete
# PSEG = PSEG complete
# Public Storage = Public Storage complete
# Pulte Homes = Pulte Homes complete
# PVH Corp. = PVH Corp. complete
# Qualcomm = Qualcomm complete
# Quest Diagnostics = Quest Diagnostics complete
# Raytheon = Raytheon complete
# Red Hat = Red Hat complete
# Regeneron Pharmaceuticals = Regeneron Pharmaceuticals complete
# Regions Financial = Regions Financial complete
# Republic Services = Republic Services complete
# Reynolds American = Reynolds American complete
# Robert Half = Robert Half complete
# Rockwell Automation = Rockwell Automation complete
# Rockwell Collins = Rockwell Collins complete
# Ross Stores = Ross Stores complete
# Royal Caribbean Cruises = Royal Caribbean Cruises complete
# Ryder System = Ryder System complete
# Salesforce = Salesforce complete
# SanDisk = SanDisk complete
# SCANA = SCANA complete
# Schlumberger = Schlumberger complete
# Scripps Networks Interactive = Scripps Networks Interactive complete
# Seagate Technology = Seagate Technology complete
# Sealed Air Corporation = Sealed Air Corporation complete
# Sempra Energy = Sempra Energy complete
# Sherwin-Williams = Sherwin-Williams complete
# Sigma-Aldrich = Sigma-Aldrich complete
# Simon Property Group = Simon Property Group complete
# Skyworks Solutions = Skyworks Solutions complete
# Snap-on = Snap-on complete
# Southern Company = Southern Company complete
# Southwest Airlines = Southwest Airlines complete
# Southwestern Energy = Southwestern Energy complete
# St. Jude Medical = St. Jude Medical complete
# Stanley Black & Decker = Stanley Black & Decker complete
# Staples = Staples complete
# Starbucks = Starbucks complete
# Starwood Hotels & Resorts = Starwood Hotels & Resorts complete
# State Street = State Street complete
# Stericycle = Stericycle complete
# Stryker = Stryker complete
# SunTrust = SunTrust complete
# Symantec = Symantec complete
# Sysco = Sysco complete
# T. Rowe Price = T. Rowe Price complete
# Target = Target complete
# TE Connectivity = TE Connectivity complete
# Tenet Healthcare = Tenet Healthcare complete
# Teradata = Teradata complete
# Tesoro Corporation = Tesoro Corporation complete
# Texas Instruments = Texas Instruments complete
# Textron = Textron complete
# The Hartford = The Hartford complete
# The Hershey Company = The Hershey Company complete
# The Home Depot = The Home Depot complete
# The J. M. Smucker Company = The J. M. Smucker Company complete
# Thermo Fisher Scientific = Thermo Fisher Scientific complete
# Tiffany & Co. = Tiffany & Co. complete
# Time Warner = Time Warner complete
# Time Warner Cable = Time Warner Cable complete
# TJX Companies = TJX Companies complete
# Tractor Supply = Tractor Supply complete
# Transocean = Transocean complete
# Travelers Companies = Travelers complete
# TripAdvisor = TripAdvisor complete
# TSYS = TSYS|Total System Services complete
# Tyco = Tyco complete
# Tyson Foods = Tyson Foods complete
# U.S. Bank = U.S. Bank complete
# Under Armour = Under Armour complete
# Union Pacific = Union Pacific complete
# United Rentals = United Rentals complete
# United Technologies = United Technologies complete
# UnitedHealth Group = UnitedHealth Group complete
# Universal Health Services = Universal Health Services complete
# Unum Group = Unum Group complete
# UPS = UPS complete
# Urban Outfitters = Urban Outfitters complete
# Valero Energy = Valero Energy complete
# Varian Medical Systems = Varian Medical Systems complete
# Verisign = Verisign complete
# Verizon = Verizon complete
# Vertex Pharmaceuticals = Vertex Pharmaceuticals complete
# VF = VF complete
# Viacom = Viacom complete
# Visa Inc. = Visa Inc. complete
# W.W. Grainger = W.W. Grainger complete
# Walgreens = Walgreens complete
# Walmart = Walmart complete
# Walt Disney Co. = Walt Disney Company complete
# Waste Management = Waste Management complete
# Waters = Waters complete
# Wells Fargo = Wells Fargo complete
# Western Digital = Western Digital complete
# Western Union = Western Union complete
# Weyerhaeuser = Weyerhaeuser complete
# Whirlpool = Whirlpool Corporation complete
# Whole Foods Market = Whole Foods Market complete
# Williams = Williams complete
# Wyndham Worldwide = Wyndham Worldwide complete
# Wynn Resorts = Wynn Resorts complete
# Xcel Energy = Xcel Energy complete
# Xerox = Xerox complete
# Xilinx = Xilinx complete
# XL Group = XL Catlin complete
# Xylem = Xylem complete
# Yahoo = Yahoo complete
# Yum! = Yum! complete
# Zions Bancorporation = Zions Bancorporation complete
# Zoetis = Zoetis complete

# %%
print(final_dic) #check that things look correct
# Out:
# [{'ceo2016': 'Inge G. Thulin', 'srleadership': '3.2', 'company': '3M', 'error': 'None', 'comp': '3.7', 'ceoratings': 482, 'numberOfRatings': 1357, 'culturevalues': '3.7', 'ceopctApprove': 86, 'id': 446, 'overall': '3.7', 'industry': 'Chemical Manufacturing', 'careerops': '3.4', 'rectofriend': 75, 'wlb': '3.5'}, {'ceo2016': 'Miles D. White', 'srleadership': '3.3', 'company': 'Abbott Labs', 'error': 'None', 'comp': '3.8', 'ceoratings': 526, 'numberOfRatings': 1019, 'culturevalues': '3.6', 'ceopctApprove': 80, 'id': 12, 'overall': '3.6', 'industry': 'Biotech & Pharmaceuticals', 'careerops': '3.3', 'rectofriend': 75, 'wlb': '3.5'}, {'ceo2016': 'Richard A. Gonzalez', 'srleadership': '3.2', 'company': 'AbbVie', 'error': 'None', 'comp': '3.9', 'ceoratings': 208, 'numberOfRatings': 557, 'culturevalues': '3.5', 'ceopctApprove': 85, 'id': 649837, 'overall': '3.6', 'industry': 'Biotech & Pharmaceuticals', 'careerops': '3.3', 'rectofriend': 71, 'wlb': '3.4'}, {'ceo2016': 'Pierre Nanterme', 'srleadership': '3.2', 'company': 'Accenture', 'error': 'None', 'comp': '3.4', 'ceoratings': 8930, 'numberOfRatings': 21188, 'culturevalues': '3.7', 'ceopctApprove': 94, 'id': 4138, 'overall': '3.7', 'industry': '', 'careerops': '3.6', 'rectofriend': 81, 'wlb': '3.2'}, {'ceo2016': 'Evan G. Greenberg', 'srleadership': '2.8', 'company': 'ACE Group', 'error': 'None', 'comp': '3.1', 'ceoratings': 55, 'numberOfRatings': 148, 'culturevalues': '3.0', 'ceopctApprove': 63, 'id': 382053, 'overall': '2.7', 'industry': 'Insurance Carriers', 'careerops': '2.6', 'rectofriend': 47, 'wlb': '2.9'}, {'ceo2016': 'Juan R. Luciano', 'srleadership': '2.9', 'company': 'ADM', 'error': 'None', 'comp': '3.3', 'ceoratings': 68, 'numberOfRatings': 345, 'culturevalues': '3.1', 'ceopctApprove': 86, 'id': 55, 'overall': '3.2', 'industry': 'Food Production', 'careerops': '3.2', 'rectofriend': 59, 'wlb': '2.9'}, {'ceo2016': 'Shantanu Narayen', 'srleadership': '3.6', 'company': 'Adobe', 'error': 'None', 'comp': '4.1', 'ceoratings': 1307, 'numberOfRatings': 2278, 'culturevalues': '4.2', 'ceopctApprove': 95, 'id': 1090, 'overall': '4.0', 'industry': 'Computer Hardware & Software', 'careerops': '3.7', 'rectofriend': 87, 'wlb': '4.1'}, {'ceo2016': 'Carlos A. Rodriguez', 'srleadership': '3.1', 'company': 'ADP', 'error': 'None', 'comp': '3.5', 'ceoratings': 1867, 'numberOfRatings': 4300, 'culturevalues': '3.5', 'ceopctApprove': 87, 'id': 64, 'overall': '3.5', 'industry': 'Staffing & Outsourcing', 'careerops': '3.4', 'rectofriend': 70, 'wlb': '3.4'}, {'ceo2016': 'Tim Whall', 'srleadership': '2.3', 'company': 'ADT Security Services', 'error': 'None', 'comp': '3.0', 'ceoratings': 57, 'numberOfRatings': 1421, 'culturevalues': '2.6', 'ceopctApprove': 64, 'id': 13956, 'overall': '2.7', 'industry': 'Security Services', 'careerops': '2.6', 'rectofriend': 39, 'wlb': '2.7'}, {'ceo2016': 'Darren R. Jackson', 'srleadership': '2.4', 'company': 'Advance Auto Parts', 'error': 'None', 'comp': '2.6', 'ceoratings': 727, 'numberOfRatings': 1592, 'culturevalues': '2.7', 'ceopctApprove': 44, 'id': 8708, 'overall': '2.9', 'industry': 'Department, Clothing, & Shoe Stores', 'careerops': '2.7', 'rectofriend': 43, 'wlb': '2.7'}, {'ceo2016': 'Nick Akins', 'srleadership': '3.5', 'company': 'AEP', 'error': 'None', 'comp': '3.8', 'ceoratings': 101, 'numberOfRatings': 232, 'culturevalues': '3.5', 'ceopctApprove': 83, 'id': 34, 'overall': '3.7', 'industry': 'Energy', 'careerops': '3.3', 'rectofriend': 68, 'wlb': '3.6'}, {'ceo2016': 'Andrés Gluski', 'srleadership': '3.4', 'company': 'AES Corporation', 'error': 'None', 'comp': '3.9', 'ceoratings': 124, 'numberOfRatings': 214, 'culturevalues': '4.0', 'ceopctApprove': 89, 'id': 291, 'overall': '3.8', 'industry': 'Utilities', 'careerops': '3.4', 'rectofriend': 87, 'wlb': '3.4'}, {'ceo2016': 'Mark T. Bertolini', 'srleadership': '2.9', 'company': 'Aetna', 'error': 'None', 'comp': '3.3', 'ceoratings': 655, 'numberOfRatings': 1374, 'culturevalues': '3.3', 'ceopctApprove': 78, 'id':  ...

# %%
final_dic[0].keys()
# Out:
# dict_keys(['ceo2016', 'srleadership', 'company', 'error', 'comp', 'ceoratings', 'numberOfRatings', 'culturevalues', 'ceopctApprove', 'id', 'overall', 'industry', 'careerops', 'rectofriend', 'wlb'])

# %%
import csv
keys = final_dic[0].keys()

#save dataset to a csv for analysis
with open('./Data/02_glassdoor_ratings.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(final_dic)
